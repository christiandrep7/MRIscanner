# %% [markdown]
# # Brain MRI Training (Colab)
#
# Use this notebook to run training on a Colab GPU.

# %%
# !nvidia-smi

# %%
# !git clone https://github.com/YOUR_USERNAME/YOUR_REPO.git
# %cd YOUR_REPO

# %%
# !pip install -r requirements.txt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python -m src.train --epochs 12 --batch-size 32

# %%
# !python -m src.evaluate --checkpoint checkpoints/best_model.pth --output-dir outputs/eval

# %%
# !cp checkpoints/best_model.pth /content/drive/MyDrive/brain_tumor_model.pth
